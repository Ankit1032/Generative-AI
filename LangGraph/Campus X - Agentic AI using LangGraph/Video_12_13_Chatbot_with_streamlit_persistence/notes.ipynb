# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For the above picture,
# 1. Where the message is being displayed is called chat_message
# 2. The box where we write the prompt is called chat_input

# %%
# in the chat_message parameter, we need to specify as who is sending the message if its user
# or AI
"""
import streamlit as st

with st.chat_message('user'):
    st.text('Hi')
"""

#Below is the screenshot of the UI --> run --> python -m streamlit run streamlit_frontend.py
# Out:
# "\nimport streamlit as st\n\nwith st.chat_message('user'):\n    st.text('Hi')\n"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"""
import streamlit as st

with st.chat_message('user'):
    st.text('Hi')

with st.chat_message('assistant'):
    st.text('How can I help you?')

"""
# Out:
# "\nimport streamlit as st\n\nwith st.chat_message('user'):\n    st.text('Hi')\n\nwith st.chat_message('assistant'):\n    st.text('How can I help you?')\n\n"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Adding Input box for user to prompt/chat
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## End Goal (Adding AI Assistant to Streamlit UI)
#
# ![image.png](attachment:image.png)
