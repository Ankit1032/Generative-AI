# %% [markdown]
# email agent
# - authenticates user
#     - only then are they allowed into the "inbox"
#     - dynamic tools and prompt on the condition of there being an email and password in state that match hardcoded
# - checks "inbox"
#     - email in tool
# - sends emails
#     - human in the loop

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class EmailContext:
    email_address: str = "julie@example.com"
    password: str = "password123"

# %%
from langchain.agents import AgentState

class AuthenticatedState(AgentState):
    authenticated: bool

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command
from langchain.messages import ToolMessage

@tool
def check_inbox() -> str:
    """Check the inbox for recent emails"""
    return """
    Hi Julie, 
    I'm going to be in town next week and was wondering if we could grab a coffee?
    - best, Jane (jane@example.com)
    """

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an response email"""
    return f"Email sent to {to} with subject {subject} and body {body}"

@tool
def authenticate(email: str, password: str, runtime: ToolRuntime) -> Command:
    """Authenticate the user with the given email and password"""
    if email == runtime.context.email_address and password == runtime.context.password:
        return Command(update={
            "authenticated": True, 
            "messages": [ToolMessage(
                "Successfully authenticated", 
                tool_call_id=runtime.tool_call_id)]
        })
    else:
        return Command(update={
            "authenticated": False,
            "messages": [ToolMessage(
                "Authentication failed", 
                tool_call_id=runtime.tool_call_id)]
        })

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

@wrap_model_call
def dynamic_tool_call(request: ModelRequest, 
handler: Callable[[ModelRequest], ModelResponse]) -> ModelResponse:

    """Allow read inbox and send email tools only if user provides correct email and password"""

    authenticated = request.state.get("authenticated")
    
    if authenticated:
        tools = [check_inbox, send_email]
    else:
        tools = [authenticate]

    request = request.override(tools=tools) 
    return handler(request)

# %%
from langchain.agents.middleware import dynamic_prompt

authenticated_prompt = "You are a helpful assistant that can check the inbox and send emails."
unauthenticated_prompt = "You are a helpful assistant that can authenticate users."

@dynamic_prompt
def dynamic_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on authentication status"""
    authenticated = request.state.get("authenticated")

    if authenticated:
        return authenticated_prompt
    else:
        return unauthenticated_prompt

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware

agent = create_agent(
    "gpt-5-nano",
    tools=[authenticate, check_inbox, send_email],
    checkpointer=InMemorySaver(),
    state_schema=AuthenticatedState,
    context_schema=EmailContext,
    middleware=[
        dynamic_tool_call, 
        dynamic_prompt,
        HumanInTheLoopMiddleware(
            interrupt_on={
                "authenticate": False,
                "check_inbox": False,
                "send_email": True,
            })
        ]
    )

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="draft 1")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)
# Out:
# Got it—could you tell me what you want Draft 1 to be about (e.g., a project proposal, email, memo, report, etc.) and any key details (topic, audience, length, tone, deadline)? If you’d like, here’s a ready-to-fill generic Draft 1 you can use as a starting point for a project proposal:
#
# Draft 1 — Project Proposal
#
# Title: [Project Name]
#
# Executive Summary
# [Provide a concise summary of the project, its purpose, expected impact, and alignment with goals.]
#
# Problem or Opportunity
# - Problem: [Describe the issue to be addressed]
# - Opportunity: [Describe the potential benefits if solved]
#
# Objectives
# - Objective 1: [Specific, measurable]
# - Objective 2: [Specific, measurable]
# - Objective 3: [Specific, measurable]
#
# Scope
# - In-Scope: [What will be included]
# - Out-of-Scope: [What will not be included]
#
# Approach / Methodology
# - Phase 1: [Describe activities, deliverables]
# - Phase 2: [Describe activities, deliverables]
# - Phase 3: [Describe activities, deliverables]
# - Deliverables: [List key outputs]
#
# Timeline
# - Milestone 1: [Date] – [Milestone]
# - Milestone 2: [Date] – [Milestone]
# - Milestone 3: [Date] – [Milestone]
#
# Budget and Resources
# - Estimated Budget: [Amount]
# - Personnel: [Roles and numbers]
# - Tools / Equipment: [List]
#
# Risks and Mitigations
# - Risk 1: [Description] – Mitigation: [Plan]
# - Risk 2: [Description] – Mitigation: [Plan]
# - Risk 3: [Description] – Mitigation: [Plan]
#
# Stakeholders and Roles
# - Sponsor: [Name]
# - Project Lead: [Name]
# - Key Stakeholders: [Names/Roles]
#
# Success Metrics
# - KPI 1: [Description and target]
# - KPI 2: [Description and target]
# - KPI 3: [Description and target]
#
# Next Steps
# - Step 1: [What happens after approval]
# - Step 2: [What happens next]
#
# Appendix (optional)
# - References, charts, or supporting materials
#
# If you share the document type and some specifics (subject, audience, tone, length), I’ll draft a precise Draft 1 tailored to your needs.

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
#
# KeyError: '__interrupt__'

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ), 
    config=config # Same thread ID to resume the paused conversation
)

print(response["messages"][-1].content)
# Out:
# Got it—could you tell me what you want Draft 1 to be about (e.g., a project proposal, email, memo, report, etc.) and any key details (topic, audience, length, tone, deadline)? If you’d like, here’s a ready-to-fill generic Draft 1 you can use as a starting point for a project proposal:
#
# Draft 1 — Project Proposal
#
# Title: [Project Name]
#
# Executive Summary
# [Provide a concise summary of the project, its purpose, expected impact, and alignment with goals.]
#
# Problem or Opportunity
# - Problem: [Describe the issue to be addressed]
# - Opportunity: [Describe the potential benefits if solved]
#
# Objectives
# - Objective 1: [Specific, measurable]
# - Objective 2: [Specific, measurable]
# - Objective 3: [Specific, measurable]
#
# Scope
# - In-Scope: [What will be included]
# - Out-of-Scope: [What will not be included]
#
# Approach / Methodology
# - Phase 1: [Describe activities, deliverables]
# - Phase 2: [Describe activities, deliverables]
# - Phase 3: [Describe activities, deliverables]
# - Deliverables: [List key outputs]
#
# Timeline
# - Milestone 1: [Date] – [Milestone]
# - Milestone 2: [Date] – [Milestone]
# - Milestone 3: [Date] – [Milestone]
#
# Budget and Resources
# - Estimated Budget: [Amount]
# - Personnel: [Roles and numbers]
# - Tools / Equipment: [List]
#
# Risks and Mitigations
# - Risk 1: [Description] – Mitigation: [Plan]
# - Risk 2: [Description] – Mitigation: [Plan]
# - Risk 3: [Description] – Mitigation: [Plan]
#
# Stakeholders and Roles
# - Sponsor: [Name]
# - Project Lead: [Name]
# - Key Stakeholders: [Names/Roles]
#
# Success Metrics
# - KPI 1: [Description and target]
# - KPI 2: [Description and target]
# - KPI 3: [Description and target]
#
# Next Steps
# - Step 1: [What happens after approval]
# - Step 2: [What happens next]
#
# Appendix (optional)
# - References, charts, or supporting materials
#
# If you share the document type and some specifics (subject, audience, tone, length), I’ll draft a precise Draft 1 tailored to your needs.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='draft 1', additional_kwargs={}, response_metadata={}, id='5fbfdb5d-51c7-49f8-b0f8-ac77b0228c5b'),
#               AIMessage(content='Got it—could you tell me what you want Draft 1 to be about (e.g., a project proposal, email, memo, report, etc.) and any key details (topic, audience, length, tone, deadline)? If you’d like, here’s a ready-to-fill generic Draft 1 you can use as a starting point for a project proposal:\n\nDraft 1 — Project Proposal\n\nTitle: [Project Name]\n\nExecutive Summary\n[Provide a concise summary of the project, its purpose, expected impact, and alignment with goals.]\n\nProblem or Opportunity\n- Problem: [Describe the issue to be addressed]\n- Opportunity: [Describe the potential benefits if solved]\n\nObjectives\n- Objective 1: [Specific, measurable]\n- Objective 2: [Specific, measurable]\n- Objective 3: [Specific, measurable]\n\nScope\n- In-Scope: [What will be included]\n- Out-of-Scope: [What will not be included]\n\nApproach / Methodology\n- Phase 1: [Describe activities, deliverables]\n- Phase 2: [Describe activities, deliverables]\n- Phase 3: [Describe activities, deliverables]\n- Deliverables: [List key outputs]\n\nTimeline\n- Milestone 1: [Date] – [Milestone]\n- Milestone 2: [Date] – [Milestone]\n- Milestone 3: [Date] – [Milestone]\n\nBudget and Resources\n- Estimated Budget: [Amount]\n- Personnel: [Roles and numbers]\n- Tools / Equipment: [List]\n\nRisks and Mitigations\n- Risk 1: [Description] – Mitigation: [Plan]\n- Risk 2: [Description] – Mitigation: [Plan]\n- Risk 3: [Description] – Mitigation: [Plan]\n\nStakeholders and Roles\n- Sponsor: [Name]\n- Project Lead: [Name]\n- Key Stakeholders: [Names/Roles]\n\nSuccess Metrics\n- KPI 1: [Description and target]\n- KPI 2: [Description and target]\n- KPI 3: [Description and target]\n\nNext Steps\n- Step 1: [What happens after approval]\n- Step 2: [What happens next]\n\nAppendix (optional)\n- References, charts, or supporting materials\n\nIf you share the document type and some specifics (subject, audience, tone, length), I’ll draft a precise Draft 1 tailored to your needs.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1339, 'prompt_tokens': 147, 'total_tokens': 1486, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cx9Ic6Dje5pFmDAtzGM9aOJMwhIJV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--7d271d37-28ec-4939-bb2f-168d9b7293b1-0', usage_metadata={'input_tokens': 147, 'output_tokens': 1339, 'total_tokens': 1486, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}})]}
