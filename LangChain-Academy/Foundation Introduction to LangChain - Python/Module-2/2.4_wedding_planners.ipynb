# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Setup Tools

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.
    You may need to make multiple queries to iteratively find the best options.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre"""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. Delegate tasks to your specialists for flights, venues and playlists.
    First find all the information you need to update the state. Once that is done you can delegate the tasks.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='78ce8dba-181e-4321-be25-323a88a048a9'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_xmgpYtAeEYMJaGmFP16aNyq2', 'function': {'arguments': '{"origin":"London","destination":"Paris","guest_count":"100","genre":"jazz"}', 'name': 'update_state'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 677, 'prompt_tokens': 293, 'total_tokens': 970, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CwmOd0roK4UPTGVtYosNLMKrxqR7k', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--e97d1900-5ad8-408e-8970-48050d0b8fbc-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'}, 'id': 'call_xmgpYtAeEYMJaGmFP16aNyq2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 677, 'total_tokens': 970, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='f6791624-e21d-4349-8b1a-4c6d6122df3b', tool_call_id='call_xmgpYtAeEYMJaGmFP16aNyq2'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6QPSMVlhPWEwamHCuIEKnxN2', 'function': {'arguments': '{}', 'name': 'search_flights'}, 'type': 'function'}, {'id': 'call_d1LlwIxC0URsmVEopRsBCSTZ', 'function': {'arguments': '{}', 'name': 'search_venues'}, 'type': 'function'}, {'id': 'call_JBFMt2Q6NQwgVfCD7X273HM4', 'function': {'arguments': '{}', 'name': 'suggest_playlist'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 382, 'prompt_tokens': 338, 'total_tokens': 720, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CwmOkKkNPGrBTdjchB932f4vhhGCK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--57e4f538-e175-476e-b66d-dcd4b1d883eb-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_6QPSMVlhPWEwamHCuIEKnxN2', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_d1LlwIxC0URsmVEopRsBCSTZ', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_JBFMt2Q6NQwgVfCD7X273HM4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 338, 'output_tokens': 382, 'total_tokens': 720, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#               ToolMessage(content='Here are the best one-way flight options from London to Paris based on price (lowest first). All are economy and on 15/06/2026.\n\nFlight options\n- Route: London LTN → Paris CDG\n  - 15/06/2026 19:40 → 15/06/2026 22:00 (1h20m) Economy\n  - Price: 49 EUR\n  - Booking: https://on.kiwi.com/VLN59J\n\n- Route: London STN → Paris CDG\n  - 15/06/2026 15:35 → 15/06/2026 17:45 (1h10m) Economy\n  - Price: 51 EUR\n  - Booking: https://on.kiwi.com/RyNTqK\n\n- Route: London LHR → Paris ORY\n  - 15/06/2026 15:05 → 15/06/2026 17:40 (1h35m) Economy\n  - Price: 51 EUR\n  - Booking: https://on.kiwi.com/UbaMot\n\n- Route: London LGW → Paris CDG\n  - 15/06/2026 18:15 → 15/06/2026 20:35 (1h20m) Economy\n  - Price: 54 EUR\n  - Booking: https://on.kiwi.com/dPbWUW\n\n- Route: London LGW → Paris CDG\n  - 15/06/2026 15:30 → 15/06/2026 16:50 (1h20m) Economy\n  - Price: 59 EUR\n  - Booking: https://on.kiwi.com/tupbjw\n\n- Route: London LGW → Paris CDG\n  - 15/06/2026 18:35 → 15/06/2026 19:55 (1h20m) Economy\n  - Price: 59 EUR\n  - Booking: https://on.kiwi.com/4VYVhE\n\n- Route: London LTN → Paris CDG\n  - 15/06/2026 12:55 → 15/06/2026 14:20 (1h25m) Economy\n  - Price: 65 EUR\n  - Booking: https://on.kiwi.com/p3DPWg\n\n- Route: London LTN → Paris CDG\n  - 15/06/2026 05:05 → 15/06/2026 06:30 (1h25m) Economy\n  - Price: 67 EUR\n  - Booking: https://on.kiwi.com/otVXpi\n\n- Route: London LTN → Paris CDG\n  - 15/06/2026 08:55 → 15/06/2026 10:20 (1h25m) Economy\n  - Price: 80 EUR\n  - Booking: https://on.kiwi.com/yBa7Bu\n\n- Route: London LHR → Paris CDG\n  - 15/06/2026 18:45 → 15/06/2026 20:00 (1h15m) Economy\n  - Price: 137 EUR\n  - Booking: https://on.kiwi.com/yhcyPZ\n\n- Route: London LGW → Paris CDG\n  - 15/06/2026 12:05 → 15/06/2026 13:25 (1h20m) Economy\n  - Price: 90 EUR\n  - Booking: https://on.kiwi.com/7E7Rkw\n\n- Route: London SEN → Paris CDG\n  - 15/06/2026 10:10 → 15/06/2026 11:20 (1h10m) Economy\n  - Price: 102 EUR\n  - Booking: https://on.kiwi.com/mQPpqA\n\n- Route: London LGW → Paris CDG\n  - 15/06/2026 09:25 → 15/06/2026 10:40 (1h15m) Economy\n  - Price: 142 EUR\n  - Booking: https://on.kiwi.com/w4slgN\n\nTop picks and quick notes\n- Best price: 49 EUR, London LTN → Paris CDG (19:40–22:00). Cheapest by far.\n- Shortest duration options (1h10m): \n  - 51 EUR, London STN → Paris CDG (15:35–17:45)\n  - 51 EUR, London SEN? No, that’s the STN and LHR options; STN is the standout short one at 1h10m.\n- Balanced option (price + reasonable time): 54 EUR, LGW → CDG (18:15–20:35) or 59 EUR LGW → CDG (15:30–16:50) / (18:35–19:55)\n\nDate advice for a Paris wedding\n- For a wedding in Paris, late spring to early summer is ideal due to pleasant weather and longer daylight. Aiming for late May, early June, or early September gives comfortable temperatures and nice venue light.\n\nRecommendation\n- If you want the absolute cheapest and don’t mind an evening departure: 49 EUR, LTN → CDG (19:40–22:00).\n- If you want the shortest flight time and a daytime arrival: 51 EUR, STN → CDG (15:35–17:45).\n\nWishing you a wonderful trip and a fantastic wedding in Paris! Fun fact: Paris is known as the City of Light and is home to the Louvre, the world’s largest and most visited art museum.', name='search_flights', id='8da9647d-bcf2-4e9f-ab67-e1e806fb0896', tool_call_id='call_6QPSMVlhPWEwamHCuIEKnxN2'),
#               ToolMessage(content='Here are Paris venues that can host around 100 guests (capacities shown as exact or up to 100, to match a 100-person wedding). I’ve ordered them with a mix of price tier and strong reviews in mind, prioritizing lower-price options first where capacity fits exactly.\n\n1) Le Cabanon (Paris 9e)\n- Capacity: privatisable up to 100 people\n- Why it fits: Private restaurant/bar setting, usually more affordable than luxury hotels\n- Price: generally budget-friendly to mid-range for Paris private events\n- Source: lecabanon.paris\n- Notes: Good option if you want an intimate, privately rented space without ultra-luxury pricing\n\n2) La Robe et la Mousse (Paris 6e)\n- Capacity: privatisation up to 100 people\n- Why it fits: Hidden-gem vibe in a historic cellarium; adaptable for a wedding reception\n- Price: mid-range (more affordable than luxury hotels)\n- Source: Privateaser listing for La Robe et la Mousse\n- Notes: Popular with private events; easy coordination through the venue\n\n3) Le Pré Catelan – Salon Empire (Bois de Boulogne, 16e)\n- Capacity: Empire salon up to 100 people\n- Why it fits: Prestigious venue tied to Lenôtre catering; refined Belle Époque setting\n- Price: high-end/luxury, but you’re paying for a signature Parisian venue with excellent service\n- Sources: Le Pré Catelan site (Salon Empire) and Lenôtre (Les Salons du Pré Catelan)\n- Notes: Large, elegant space with terrace options; ideal for a classic, upscale wedding\n\n4) The Peninsula Paris (8th/16th arrondissement area)\n- Capacity: ballroom can host up to 100 guests for a seated dinner\n- Why it fits: Ultra-luxury hotel with flawless service and culinary caliber\n- Price: premium/luxury\n- Source: Peninsula Paris site (weddings and events)\n- Notes: Elegantly designed spaces, excellent for a high-end Paris wedding\n\n5) Four Seasons Hotel George V, Paris (8e)\n- Capacity: Les Salons de réception can accommodate up to 100 people for receptions\n- Why it fits: Iconic luxury hotel with world-class service and catering\n- Price: premium/luxury\n- Source: Four Seasons Hotel George V Paris weddings page\n- Notes: Outstanding reputation; ideal if you want a blockbuster Paris wedding with top-tier coordination\n\nAdditional context\n- If you’re open to “up to 100” rather than strictly “exactly 100,” you can also consider venues that list 100-capacity options within larger private spaces. Examples seen in market listings include venues with 100–200 range or 100–400 range; they can often be narrowed to a 100-person guest count with proper layout and catering.\n- The luxury hotels (Peninsula Paris, Four Seasons George V) tend to have the strongest overall reviews and service levels, but they come with higher price brackets. Le Pré Catelan offers a prestigious Lenôtre setup at a premium, while Le Cabanon and La Robe et la Mousse provide more budget-friendly private settings with solid reputations.\n\nIf you want, I can narrow this further to show current availability and estimated price ranges for your preferred dates, or add a few more options that meet the exact 100-capacity criterion.', name='search_venues', id='1107e3dd-5e39-44f2-8b96-b639dd9dd806', tool_call_id='call_d1LlwIxC0URsmVEopRsBCSTZ'),
#               ToolMessage(content="Here’s a wedding-friendly jazz playlist pulled from the Jazz tracks in the database. It mixes breezy bossa nova vibes with smooth jazz ballads for a romantic and easy-to-dance atmosphere. The prices shown are per track (all $0.99 in this set).\n\nCurated playlist (12 tracks)\n1) Outra Vez — Antônio Carlos Jobim — 2:06 — $0.99\n2) Fotografia — Antônio Carlos Jobim — 2:09 — $0.99\n3) Desafinado — Antônio Carlos Jobim — 3:05 — $0.99\n4) Samba De Uma Nota Só (One Note Samba) — Antônio Carlos Jobim — 2:17 — $0.99\n5) Se Todos Fossem Iguais A Você (Instrumental) — Antônio Carlos Jobim — 2:14 — $0.99\n6) Angela — Antônio Carlos Jobim — 2:49 — $0.99\n7) Por Causa De Você — Antônio Carlos Jobim — 2:49 — $0.99\n8) Lament — Miles Davis — 2:14 — $0.99\n9) The Meaning Of The Blues — Miles Davis — 2:48 — $0.99\n10) Generique — Miles Davis — 2:48 — $0:99\n11) I Don't Wanna Be Kissed (By Anyone But You) — Miles Davis — 3:11 — $0.99\n12) Jeru — Miles Davis — 3:13 — $0.99\n\nTotal duration: 31 minutes 43 seconds\nTotal price: $11.88\n\nNotes and tips\n- This set starts with warm, Latin-tinged jazz (Jobim), moves through romantic Miles Davis selections, and ends with a gentle swing/ballad vibe. It’s great for cocktail hour or a relaxed reception segment.\n- If you’d like a longer program, I can add more tracks (e.g., more Jobim or other vocal/instrumental jazz standards) to hit 60–90 minutes or tailor to a specific tempo curve (slow intro, swing portion, then a dance-friendly finale).\n\nWould you like me to:\n- Extend the playlist to a longer duration (e.g., 60–90 minutes) with additional tracks?\n- Rebalance for more dance-friendly tempo and a few more upbeat numbers?\n- Export this as a ready-to-use tracklist or shuffle it for a different vibe?", name='suggest_playlist', id='78a2c5f6-fb32-45f6-a94a-c4ce2aaf75f3', tool_call_id='call_JBFMt2Q6NQwgVfCD7X273HM4'),
#               AIMessage(content='Fantastic! I’ve got a solid starting suite for your Paris wedding, with 100 guests and a jazz vibe. Here’s a clear motion plan and options to choose from.\n\nWhat we’ve gathered so far\n- Origin: London\n- Destination: Paris\n- Guest count: 100\n- Music vibe: Jazz (romantic, easy to dance to)\n\nFlight options for guests (London → Paris)\n- Cheapest overall: 49 EUR\n  - Route: London LTN → Paris CDG\n  - 19:40–22:00 (1h20m)\n  - Booking: 49 EUR\n- Shortest duration (about 1h10m): 51 EUR\n  - Route: London STN → Paris CDG\n  - 15:35–17:45\n  - Booking: 51 EUR\n- Other solid options (reasonable price, good times):\n  - LGW → CDG: 18:15–20:35, 54 EUR\n  - LGW → CDG: 15:30–16:50, 59 EUR\n  - LHR → CDG: 18:45–20:00, 137 EUR (premium option)\n- Notes: These are one-way options. We can block a group of seats, coordinate arrivals to fit the wedding day schedule, and choose a main arrival window (e.g., group flight arrivals within a 2–3 hour window).\n\nVenues for 100 guests in Paris (shortlist with vibe and capacity)\n1) Le Cabanon (Paris 9e)\n   - Capacity: privately rentable up to 100\n   - Vibe: intimate private restaurant/bar\n   - Price: budget-friendly to mid-range\n   - Why consider: great value, flexible layout\n\n2) La Robe et la Mousse (Paris 6e)\n   - Capacity: privatization up to 100\n   - Vibe: historic, intimate cellar/private setting\n   - Price: mid-range\n   - Why consider: intimate charm with good event coordination\n\n3) Le Pre Catelan – Salon Empire (Bois de Boulogne, 16e)\n   - Capacity: up to 100\n   - Vibe: prestigious, refined Belle Epoque\n   - Price: premium\n   - Why consider: iconic setting, excellent catering partners\n\n4) The Peninsula Paris (8e/16e)\n   - Capacity: ballroom up to 100\n   - Vibe: ultra-luxury hotel, flawless service\n   - Price: premium/luxury\n   - Why consider: top-tier experience, seamless coordination\n\n5) Four Seasons Hotel George V, Paris (8e)\n   - Capacity: Les Salons de Réception up to 100\n   - Vibe: iconic luxury, world-class catering\n   - Price: premium\n   - Why consider: blockbuster Paris wedding feel, outstanding service\n\nPlaylist for the jazz wedding (current set)\n- 12 tracks, around 31:43 total\n- Mix: Jobim bossa nova / Miles Davis smoother jazz\n- Price: $11.88 total for the set\n- Use: Great for cocktail hour and dinner; can extend for 60–90 minutes; easy to re-balance for more dance-friendly tempos\n- Next steps: I can extend this to 60–90 minutes, tailor for a dance-heavy portion, or export a ready-to-use tracklist.\n\nRecommendations (quick picks)\n- For venue: pick 2–3 top fits to check availability (Le Cabanon for budget-friendly intimacy; Le Pre Catelan for prestige; Peninsula or Four Seasons for luxury). If you want a classic Paris luxury feel, I’d lean toward Le Pre Catelan, Peninsula Paris, or Four Seasons George V.\n- For flights: book a group block around a main arrival window (e.g., a 2–3 hour window from London airports) and have a backup option for guests arriving earlier or later.\n- For music: keep the current jazz vibe as a base, extend to 60–90 minutes for reception, and add a few upbeat jazz/neo-swing tracks for dancing after dinner.\n\nWhat I need from you to move forward\n- Date or date range for the wedding in Paris (and preferred arrival window for guests).\n- Airport preference for London (LHR, LGW, STN, LTN) or a mix may be fine.\n- Budget guidance for:\n  - Venue (rough range per head or total)\n  - Flight blocks (group rate target)\n  - Other essentials (catering style, bar, decor)\n- Preference among the venues:\n  - Which 2–3 are your top picks to check availability for your date?\n- Do you want me to:\n  - Place holds/availability checks on your top venues for your date?\n  - Request group-flight options and block seats for the guest cohort?\n  - Prepare a fully tailored timeline (pre-wedding events, ceremony, cocktails, dinner, dancing)?\n\nNext steps I can take as soon as you share a date and priori ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic! I’ve got a solid starting suite for your Paris wedding, with 100 guests and a jazz vibe. Here’s a clear motion plan and options to choose from.
#
# What we’ve gathered so far
# - Origin: London
# - Destination: Paris
# - Guest count: 100
# - Music vibe: Jazz (romantic, easy to dance to)
#
# Flight options for guests (London → Paris)
# - Cheapest overall: 49 EUR
#   - Route: London LTN → Paris CDG
#   - 19:40–22:00 (1h20m)
#   - Booking: 49 EUR
# - Shortest duration (about 1h10m): 51 EUR
#   - Route: London STN → Paris CDG
#   - 15:35–17:45
#   - Booking: 51 EUR
# - Other solid options (reasonable price, good times):
#   - LGW → CDG: 18:15–20:35, 54 EUR
#   - LGW → CDG: 15:30–16:50, 59 EUR
#   - LHR → CDG: 18:45–20:00, 137 EUR (premium option)
# - Notes: These are one-way options. We can block a group of seats, coordinate arrivals to fit the wedding day schedule, and choose a main arrival window (e.g., group flight arrivals within a 2–3 hour window).
#
# Venues for 100 guests in Paris (shortlist with vibe and capacity)
# 1) Le Cabanon (Paris 9e)
#    - Capacity: privately rentable up to 100
#    - Vibe: intimate private restaurant/bar
#    - Price: budget-friendly to mid-range
#    - Why consider: great value, flexible layout
#
# 2) La Robe et la Mousse (Paris 6e)
#    - Capacity: privatization up to 100
#    - Vibe: historic, intimate cellar/private setting
#    - Price: mid-range
#    - Why consider: intimate charm with good event coordination
#
# 3) Le Pre Catelan – Salon Empire (Bois de Boulogne, 16e)
#    - Capacity: up to 100
#    - Vibe: prestigious, refined Belle Epoque
#    - Price: premium
#    - Why consider: iconic setting, excellent catering partners
#
# 4) The Peninsula Paris (8e/16e)
#    - Capacity: ballroom up to 100
#    - Vibe: ultra-luxury hotel, flawless service
#    - Price: premium/luxury
#    - Why consider: top-tier experience, seamless coordination
#
# 5) Four Seasons Hotel George V, Paris (8e)
#    - Capacity: Les Salons de Réception up to 100
#    - Vibe: iconic luxury, world-class catering
#    - Price: premium
#    - Why consider: blockbuster Paris wedding feel, outstanding service
#
# Playlist for the jazz wedding (current set)
# - 12 tracks, around 31:43 total
# - Mix: Jobim bossa nova / Miles Davis smoother jazz
# - Price: $11.88 total for the set
# - Use: Great for cocktail hour and dinner; can extend for 60–90 minutes; easy to re-balance for more dance-friendly tempos
# - Next steps: I can extend this to 60–90 minutes, tailor for a dance-heavy portion, or export a ready-to-use tracklist.
#
# Recommendations (quick picks)
# - For venue: pick 2–3 top fits to check availability (Le Cabanon for budget-friendly intimacy; Le Pre Catelan for prestige; Peninsula or Four Seasons for luxury). If you want a classic Paris luxury feel, I’d lean toward Le Pre Catelan, Peninsula Paris, or Four Seasons George V.
# - For flights: book a group block around a main arrival window (e.g., a 2–3 hour window from London airports) and have a backup option for guests arriving earlier or later.
# - For music: keep the current jazz vibe as a base, extend to 60–90 minutes for reception, and add a few upbeat jazz/neo-swing tracks for dancing after dinner.
#
# What I need from you to move forward
# - Date or date range for the wedding in Paris (and preferred arrival window for guests).
# - Airport preference for London (LHR, LGW, STN, LTN) or a mix may be fine.
# - Budget guidance for:
#   - Venue (rough range per head or total)
#   - Flight blocks (group rate target)
#   - Other essentials (catering style, bar, decor)
# - Preference among the venues:
#   - Which 2–3 are your top picks to check availability for your date?
# - Do you want me to:
#   - Place holds/availability checks on your top venues for your date?
#   - Request group-flight options and block seats for the guest cohort?
#   - Prepare a fully tailored timeline (pre-wedding events, ceremony, cocktails, dinner, dancing)?
#
# Next steps I can take as soon as you share a date and priorities
# - Check current availability and rough pricing for your top 2–3 venues.
# - Coordinate a group-flight block from London for your guest range, with suggested arrival windows.
# - Fine-tune the jazz playlist (extend duration, adjust tempo for cocktail/dinner/dance segments) and deliver a ready-to-use tracklist.
# - Draft a preliminary wedding itinerary and budget outline for your review.
#
# If you’re happy with the direction, tell me:
# - Your preferred date range
# - Your top 2 venue choices
# - Whether you want me to secure a group flight block and start availability checks
#
# I’ll take it from there and keep you updated with concrete options, quotes, and a detailed plan.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
